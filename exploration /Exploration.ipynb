# %% [markdown]
# # Croix Rouge FR // Data For Good

# %%
import pandas as pd
import db
from db import DB

# %%
db = DB(username="martin", hostname="localhost",dbname="redcross",dbtype="mysql")
# Out:
# Refreshing schema. Please wait...done!

# %%
db.tables
# Out:
# +-------------------------------+----------------------------------------------------------------------------------+
# | Table                         | Columns                                                                          |
# +-------------------------------+----------------------------------------------------------------------------------+
# | #Tableau_sid_000000E9_4_Group | DATE (copie) (groupe), DATE (copie)                                              |
# | ART_DIS_FAMILLE               | ID_MOIS, CD_U2A, CD_FAM_ART, QTE_NETTE, POIDS_NET                                |
# | ART_DIS_SURFAMILLE            | ID_MOIS, CD_U2A, CD_SUR_FAM_ART, QTE_NETTE, POIDS_NET                            |
# | ART_TONNAGE                   | ID_MOIS, CD_U2A, QTE_NETTE_TOTALE, POIDS_NETTE_TOTALE, QTE_NETTE_PEAD, POIDS_NET |
# |                               | TE_PEAD                                                                          |
# | BEN_CHARGES_FOURCH            | ID_MOIS, CD_U2A, NB_FOYERS_CHARGES_0_99, NB_AD_CHARGES_0_99, NB_FOYERS_CHARGES_1 |
# |                               | 00_199, NB_AD_CHARGES_100_199, NB_FOYERS_CHARGES_200_299, NB_AD_CHARGES_200_299, |
# |                               |  NB_FOYERS_CHARGES_300_399, NB_AD_CHARGES_300_399, NB_FOYERS_CHARGES_400_ET_PLUS |
# |                               | , NB_AD_CHARGES_400_ET_PLUS                                                      |
# | BEN_CHARGES_FOURCH_N          | ID_MOIS, CD_U2A, NB_FOYERS_CHARGES_0_99, NB_AD_CHARGES_0_99, NB_FOYERS_CHARGES_1 |
# |                               | 00_199, NB_AD_CHARGES_100_199, NB_FOYERS_CHARGES_200_299, NB_AD_CHARGES_200_299, |
# |                               |  NB_FOYERS_CHARGES_300_399, NB_AD_CHARGES_300_399, NB_FOYERS_CHARGES_400_ET_PLUS |
# |                               | , NB_AD_CHARGES_400_ET_PLUS                                                      |
# | BEN_CHARGES_NB_FICHES         | ID_MOIS, CD_U2A, NB                                                              |
# | BEN_CHARGES_NB_FICHES_N       | ID_MOIS, CD_U2A, NB                                                              |
# | BEN_CHARGES_POSTE             | ID_MOIS, CD_U2A, CD_REVENU, NB                                                   |
# | BEN_CODE_FOYER_EFF            | ID_MOIS, CD_U2A, CD_BENEF, CD_STATUT_FOYER                                       |
# | BEN_CRIT_ELIG                 | ID_MOIS, CD_U2A, CD_CRIT_REF, NB                                                 |
# | BEN_DUREE_DROIT               | ID_MOIS, CD_U2A, num_foyers_duree_moins_un_an, num_ad_duree_moins_un_an, num_foy |
# |                               | ers_duree_plus_un_an, num_ad_duree_plus_un_an, num_foyers_date_invalide, num_ad_ |
# |                               | date_invalide                                                                    |
# | BEN_DUREE_FOYER               | ID_MOIS, CD_U2A, MOYENNE, MOYENNE_BASSE, MOYENNNE_HAUTE                          |
# | BEN_DUREE_FOYER_N             | ID_MOIS, CD_U2A, MOYENNE, MOYENNE_BASSE, MOYENNNE_HAUTE                          |
# | BEN_NB_FOYER_EFF              | ID_MOIS, CD_U2A, CD_STATUT_FOYER_BEN, NB_FOYER_EFF                               |
# | BEN_REVENUS_FOURCH            | ID_MOIS, CD_U2A, NB_FOYERS_REVENUS_0_99, NB_AD_REVENUS_0_99, NB_FOYERS_REVENUS_1 |
# |                               | 00_199, NB_AD_REVENUS_100_199, NB_FOYERS_REVENUS_200_299, NB_AD_REVENUS_200_299, |
# |                               |  NB_FOYERS_REVENUS_300_399, NB_AD_REVENUS_300_399, NB_FOYERS_REVENUS_400_ET_PLUS |
# |                               | , NB_AD_REVENUS_400_ET_PLUS                                                      |
# | BEN_REVENUS_FOURCH_N          | ID_MOIS, CD_U2A, NB_FOYERS_REVENUS_0, NB_AD_REVENUS_0, NB_FOYERS_REVENUS_1_499,  |
# |                               | NB_AD_REVENUS_1_499, NB_FOYERS_REVENUS_500_899, NB_AD_REVENUS_500_899, NB_FOYERS |
# |                               | _REVENUS_900_et_plus, NB_AD_REVENUS_900_et_plus                                  |
# | BEN_REVENUS_FOURCH_NEW        | ID_MOIS, CD_U2A, NB_FOYERS_REVENUS_0, NB_AD_REVENUS_0, NB_FOYERS_REVENUS_1_499,  |
# |                               | NB_AD_REVENUS_1_499, NB_FOYERS_REVENUS_500_899, NB_AD_REVENUS_500_899, NB_FOYERS |
# |                               | _REVENUS_900_et_plus, NB_AD_REVENUS_900_et_plus                                  |
# | BEN_REVENUS_NB_FICHES         | ID_MOIS, CD_U2A, NB                                                              |
# | BEN_REVENUS_NB_FICHES_N       | ID_MOIS, CD_U2A, NB                                                              |
# | BEN_REVENUS_POSTE             | ID_MOIS, CD_U2A, CD_REVENU, NB                                                   |
# | BEN_SEXE_AYANTDROIT           | ID_MOIS, CD_U2A, CD_SEXE, NB                                                     |
# | BEN_SEXE_AYANTDROIT_N         | ID_MOIS, CD_U2A, CD_SEXE, NB                                                     |
# | BEN_SEXE_CHEFFOYER            | ID_MOIS, CD_U2A, CD_SEXE, NB                                                     |
# | BEN_SEXE_CHEFFOYER_N          | ID_MOIS, CD_U2A, CD_SEXE, NB                                                     |
# | BEN_STATUT_FOYER              | ID_MOIS, CD_U2A, CD_STATUT_FOYER_BEN, NB_FOYER                                   |
# | BEN_STATUT_FOYER_N            | ID_MOIS, CD_U2A, CD_STATUT_FOYER_BEN, NB_FOYER                                   |
# | BEN_TRANCHE_AGE               | ID_MOIS, CD_U2A, CD_TRANCHE_AGE, NB                                              |
# | BEN_TYPO_FOYER                | ID_MOIS, CD_U2A, CD_TYPO_FOYER_BEN, NB                                           |
# | BEN_TYPO_FOYER_N              | ID_MOIS, CD_U2A, CD_TYPO_FOYER_BEN, NB                                           |
# | BEN_TYP_FAMILLE               | ID_MOIS, CD_U2A, CD_TYP_FAM, NB                                                  |
# | BEN_TYP_FOYER                 | ID_MOIS, CD_U2A, CD_TYP_FOYER_BEN, NB                                            |
# | BEN_TYP_FOYER_N               | ID_MOIS, CD_U2A, CD_TYP_FOYER_BEN, NB                                            |
# | DIM_CHARGE                    | CD_CHARGE, LB_CHARGE                                                             |
# | DIM_CRIT_REF                  | CD_CRIT_REF, LB_CRIT_REF                                                         |
# | DIM_DATE                      | ID_MOIS, NUM_MOIS, NUM_INV_MOIS, LB_MOIS, NUM_TRIM, NUM_INV_TRIM, LB_TRIM, NUM_A |
# |                               | NNEE, LIB_ANNEE, DEB_MOIS, FIN_MOIS, NB_JR_MOIS, NB_JR_OUVRES_MOIS               |
# | DIM_ENS_FOUR                  | CD_ENS_FOUR, LB_ENS_FOUR                                                         |
# | DIM_FAM_ART                   | CD_FAM_ART, LB_FAM_ART                                                           |
# | DIM_FOUR                      | CD_FOUR, LB_FOUR, CD_TYP_FOUR, CD_GRP_FOUR, CD_ENS_FOUR                          |
# | DIM_FREQ_PASSAGE              | CD_FREQ_PASSAGE, LB_FREQ_PASSAGE                                                 |
# | DIM_GRP_FOUR                  | CD_GRP_FOUR, LB_GRP_FOUR                                                         |
# | DIM_HIER_STR                  | CD_STR, LB_STR, CD_PERE, LB_PERE, CD_GPERE, LB_GPERE, CD_GGPERE, LB_GGPERE       |
# | DIM_LIG_ART                   | CD_LIG_ART, LB_LIG_ART                                                           |
# | DIM_ORI_RECPT                 | CD_ORI_RECPT, LB_ORI_RECPT                                                       |
# | DIM_REVENU                    | CD_REVENU, LB_REVENU                                                             |
# | DIM_SEXE                      | CD_SEXE, LB_SEXE                                                                 |
# | DIM_SS_FAM_ART                | CD_SS_FAM_ART, LB_SS_FAM_ART                                                     |
# | DIM_STATUT_FOYER_BEN          | CD_STATUT_FOYER_BEN, LB_STATUT_FOYER_BEN                                         |
# | DIM_STR_DEPT                  | CD_STR, CD_DEPT                                                                  |
# | DIM_SUR_FAM_ART               | CD_SUR_FAM_ART, LB_SUR_FAM_ART                                                   |
# | DIM_TRANCHE_AGE               | CD_TRANCHE_AGE, LB_TRANCHE_AGE                                                   |
# | DIM_TYPO_FOYER_BEN            | CD_TYPO_FOYER_BEN, LB_TYPO_FOYER_BEN                                             |
# | DIM_TYP_FOUR                  | CD_TYP_FOUR, LB_TYP_FOUR                                                         |
# | DIM_TYP_FOYER_BEN             | CD_TYP_FOYER_BEN, LB_TYP_FOYER_BEN                                               |
# | DIM_U2A                       | CD_U2A, LB_U2A, CD_STR, CD_DEPT, LB_DEPT, CD_REGION, LB_REGION                   |
# | DIS_FOYER                     | ID_MOIS, CD_U2A, NB_FOYER_BEN, NB_AYANTDROIT_FOYER_BEN, NB_DIS_FOYER_BEN, NB_DIS |
# |                               | _AYANTDROIT_BEN, NB_DIS_AYANTDROIT_BEN_CUM                                       |
# | DIS_FOYER_TYPE                | ID_MOIS, CD_U2A, CD_TYP_FOYER_BEN, NB_DIS, NB_FOYERS_SERVIS, NB_FOYERS_SERVIS_CU |
# |                               | M, NB_AYANTDROITS_SERVIS, NB_AYANTDROITS_SERVIS_CUM                              |
# | DIS_FREQUENCE                 | ID_MOIS, CD_U2A, FREQ_PASSAGE_MOYENNE, FREQ_PASSAGE_HAUTE, FREQ_PASSAGE_BASSE    |
# | DIS_TRANCHE_AGE               | ID_MOIS, CD_U2A, CD_TRANCHE_AGE, NB                                              |
# | STO_ENTR_PEADPNAA             | ID_MOIS, CD_U2A, POIDNETTOT                                                      |
# | STO_FOUR_ORI                  | ID_MOIS, CD_U2A, CD_ORI_RECPT, CD_FOUR, CD_UNITE, CD_LIG_ART, CD_SUR_FAM_ART, CD |
# |                               | _FAM_ART, CD_SS_FAM_ART, POIDS_NET, QTE_NETTE                                    |
# +-------------------------------+----------------------------------------------------------------------------------+

# %%
db.query("SELECT * FROM STO_FOUR_ORI LIMIT 100")
# Out:
#     ID_MOIS CD_U2A CD_ORI_RECPT     CD_FOUR CD_UNITE CD_LIG_ART  \
# 0    201101  U8201   BA HORS EU   FFFBA0031       UN        ALI
# 92   201101  U3301    ACHAT MAG        AIDA       UN        ALI
# 93   201101  U2201   BA HORS EU   FFFBA0022       UN        ALI
# 94   201101  U2201   BA HORS EU        AIDA       UN        ALI
# 95   201101  U2201   BA HORS EU        AIDA       UN        ALI
# 96   201101  U4401   BA HORS EU  FFBA0044SN       UN        ALI
# 97   201101  U3301    ACHAT MAG        AIDA       UN        ALI
# 98   201101  U7101   BA HORS EU   FFFBA0021       UN        ALI
# 99   201101  U8201   BA HORS EU   FFFBA0031       UN        ALI
#
#    CD_SUR_FAM_ART CD_FAM_ART CD_SS_FAM_ART  POIDS_NET  QTE_NETTE
# 0              FL        LGM           PLG     31.660        105
# 1              FL        LGM           PLG      4.600         13
# 2              FL        LGM           SPL     19.506         33
# 3              FL        LGM           CNC      8.140         37
# 4              FL        LGM           CNC      0.380          1
# 5             VOP        VAD           PVN    251.680        322
# 6             PGS        PGS           RAV      7.200          9
# 7             FEC        FER           SFR      2.208          6
# 8             FEC        FER           SFR      0.067          1
# 9             VOP        POS           CSP      4.780         32
# 10            VOP        POS           CSP      1.120          8
# 11            VOP        VAD           SPV      0.000          1
# 12            LPL         LT           LTB     16.500         19
# 13            LPL         LT           LTB      6.500         10
# 14            FEC        FER           PAT     23.000         31
# 15            LPL        FMG           FMG     14.850        109
# 16            FEC        FNR           CFB      1.800          3
# 17            FEC        FER           PFR      2.340         76
# 18            PGS        PGS           BSK     42.505        608
# 19            FEC        FNR           PCE      8.960         28
# 20            FEC        FER           PNC      4.100         13
# 21            FEC        FER           PRF      5.505         22
# 22            PGS        PGS           TTR      0.460         50
# 23            FEC        FER           PAT      1.500          4
# 24            MTG        MAV           MYN      2.160         12
# 25            MTG        MGA           CFC     13.550         33
# 26            PGS        PGS           BSC     13.500          9
# 27            PGS        PGS           CSC      3.550         10
# 28            PGS        PGS           CFS      5.000         35
# 29            PGS        PGS           SUC     15.750         19
# ..            ...        ...           ...        ...        ...
# 70            CDM        CDM           VNG      1.500         14
# 71            VOP        VAD           CSV      3.360          4
# 72             FL        LGM           CSL      0.000         60
# 73            FEC        FER           FRN      0.000         48
# 74            CFT        CAF           CAF      0.000          1
# 75            PGS        PGS           MTD      0.280          1
# 76            VOP        POS           CSP      1.410          4
# 77            VOP        VAD           CSV      0.840          1
# 78            PGS        PGS           PTT      0.500          1
# 79            PGS        PGS           CFS      0.000          3
# 80            VOP        VAD           CSV      0.426          2
# 81            PGS        PGS           PTT      2.250          3
# 82            PGS        PGS           CRC      0.840          2
# 83            PGS        PGS           CSC      1.000          2
# 84            FEC        FER           PRF     21.500         43
# 85            PGS        PGS           BSK      1.400         16
# 86             FL        LGM           PLG      8.240         21
# 87             FL        LGM           SPL     18.000         38
# 88            VOP        VAD           PVN     15.590         20
# 89             FL        LGM           SPL      2.000          5
# 90             FL        LGM           CSL     73.860        122
# 91            PGS        PGS           CRC     12.350         67
# 92             FL        LGM           PLG      2.300          3
# 93            VOP        VAD           CSV      4.740          9
# 94            VOP        VAD           CSV      1.990          3
# 95            VOP        POS           CSP    102.630        541
# 96            VOP        VAD           PVN      5.000          6
# 97            PGS        PGS           CRC      5.663         33
# 98            LPL         LT           LTB      9.000         10
# 99            PGS        PGS           CSC      5.355         14
#
# [100 rows x 11 columns]
